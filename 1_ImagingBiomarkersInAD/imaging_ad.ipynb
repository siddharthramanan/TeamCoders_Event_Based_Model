# %% [markdown]
# # Workbook on Biomdedical Imaging extraction
# This workbook will test some of the skills that we demonstrated in the demonstration notebook. You will find instructions for what to do in each step followed by an empty code cell to enter your work. Don't forget that you will need to import the appropriate packages for this weok.

# %%
# Put your import statements here.

# %% [markdown]
# ## Step 1 - Load an MRI image
# Please find the images for subject **INSERT SUBJECT ID WITH VMRI and PET HERE** in the directory marked . Download them locally (that does not need to be part of your code) and load the image up. Print out the following information:
# * Image dimensions
# * Intensity Range
# * Voxel to World Affine Transformation

# %%
# Your answer to Step 1
# Below put your code that will load up the image and prodcued the requested information

# %% [markdown]
# ## Step 2 - Initial Mask
# Now we are going to register the image to a common standard space and apply the mask to the image.
